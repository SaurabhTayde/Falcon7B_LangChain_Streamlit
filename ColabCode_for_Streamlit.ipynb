# %%
# !pip install -q transformers einops accelerate langchain bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 57.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 kB 25.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 71.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 11.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 27.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 99.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 79.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 11.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 5.7 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Mon Jun 26 20:29:01 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    24W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from langchain import HuggingFacePipeline
from transformers import AutoTokenizer, pipeline
import torch

model = "tiiuae/falcon-7b-instruct" #tiiuae/falcon-40b-instruct

tokenizer = AutoTokenizer.from_pretrained(model)

pipeline = pipeline(
    "text-generation", #task
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto",
    max_length=400,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id
)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/220 [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.73M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/281 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/667 [00:00<?, ?B/s]
# Downloading (…)/configuration_RW.py:   0%|          | 0.00/2.61k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/tiiuae/falcon-7b-instruct:
# - configuration_RW.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# Downloading (…)main/modelling_RW.py:   0%|          | 0.00/47.5k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/tiiuae/falcon-7b-instruct:
# - modelling_RW.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# Downloading (…)model.bin.index.json:   0%|          | 0.00/16.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)l-00001-of-00002.bin:   0%|          | 0.00/9.95G [00:00<?, ?B/s]
# Downloading (…)l-00002-of-00002.bin:   0%|          | 0.00/4.48G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.
# The model 'RWForCausalLM' is not supported for text-generation. Supported models are ['BartForCausalLM', 'BertLMHeadModel', 'BertGenerationDecoder', 'BigBirdForCausalLM', 'BigBirdPegasusForCausalLM', 'BioGptForCausalLM', 'BlenderbotForCausalLM', 'BlenderbotSmallForCausalLM', 'BloomForCausalLM', 'CamembertForCausalLM', 'CodeGenForCausalLM', 'CpmAntForCausalLM', 'CTRLLMHeadModel', 'Data2VecTextForCausalLM', 'ElectraForCausalLM', 'ErnieForCausalLM', 'GitForCausalLM', 'GPT2LMHeadModel', 'GPT2LMHeadModel', 'GPTBigCodeForCausalLM', 'GPTNeoForCausalLM', 'GPTNeoXForCausalLM', 'GPTNeoXJapaneseForCausalLM', 'GPTJForCausalLM', 'LlamaForCausalLM', 'MarianForCausalLM', 'MBartForCausalLM', 'MegaForCausalLM', 'MegatronBertForCausalLM', 'MvpForCausalLM', 'OpenLlamaForCausalLM', 'OpenAIGPTLMHeadModel', 'OPTForCausalLM', 'PegasusForCausalLM', 'PLBartForCausalLM', 'ProphetNetForCausalLM', 'QDQBertLMHeadModel', 'ReformerModelWithLMHead', 'RemBertForCausalLM', 'RobertaForCausalLM', 'RobertaPreLayerNormForCausalLM', 'RoCBertForCausalLM', 'RoFormerForCausalLM', 'RwkvForCausalLM', 'Speech2Text2ForCausalLM', 'TransfoXLLMHeadModel', 'TrOCRForCausalLM', 'XGLMForCausalLM', 'XLMWithLMHeadModel', 'XLMProphetNetForCausalLM', 'XLMRobertaForCausalLM', 'XLMRobertaXLForCausalLM', 'XLNetLMHeadModel', 'XmodForCausalLM'].

# %%
llm = HuggingFacePipeline(pipeline = pipeline, model_kwargs = {'temperature':0.2})

# %%
# !pip install chainlit
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting chainlit
#   Downloading chainlit-0.4.101-py3-none-any.whl (751 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 751.2/751.2 kB 13.7 MB/s eta 0:00:00
# Collecting aiofiles<24.0.0,>=23.1.0 (from chainlit)
#   Downloading aiofiles-23.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.4 in /usr/local/lib/python3.10/dist-packages (from chainlit) (3.8.4)
# Collecting asyncer<0.0.3,>=0.0.2 (from chainlit)
#   Downloading asyncer-0.0.2-py3-none-any.whl (8.3 kB)
# Collecting auth0-python<5.0.0,>=4.1.1 (from chainlit)
#   Downloading auth0_python-4.3.0-py2.py3-none-any.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 kB 13.7 MB/s eta 0:00:00
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from chainlit) (8.1.3)
# Requirement already satisfied: dataclasses_json<0.6.0,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from chainlit) (0.5.8)
# Collecting fastapi<0.97.0,>=0.96.0 (from chainlit)
#   Downloading fastapi-0.96.1-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 kB 8.0 MB/s eta 0:00:00
# Collecting fastapi-socketio<0.0.11,>=0.0.10 (from chainlit)
#   Downloading fastapi_socketio-0.0.10-py3-none-any.whl (7.4 kB)
# Collecting openai<0.28.0,>=0.27.7 (from chainlit)
#   Downloading openai-0.27.8-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<2.0.0,>=1.10.8 in /usr/local/lib/python3.10/dist-packages (from chainlit) (1.10.9)
# Collecting python-dotenv<2.0.0,>=1.0.0 (from chainlit)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting python-graphql-client<0.5.0,>=0.4.3 (from chainlit)
#   Downloading python_graphql_client-0.4.3-py3-none-any.whl (4.9 kB)
# Collecting syncer<3.0.0,>=2.0.3 (from chainlit)
#   Downloading syncer-2.0.3.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tomli<3.0.0,>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from chainlit) (2.0.1)
# Collecting uptrace<2.0.0,>=1.18.0 (from chainlit)
#   Downloading uptrace-1.18.0-py3-none-any.whl (8.6 kB)
# Collecting uvicorn<0.23.0,>=0.22.0 (from chainlit)
#   Downloading uvicorn-0.22.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.2 MB/s eta 0:00:00
# Collecting watchfiles<0.20.0,>=0.19.0 (from chainlit)
#   Downloading watchfiles-0.19.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 51.0 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.4->chainlit) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.4->chainlit) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.4->chainlit) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.4->chainlit) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.4->chainlit) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.4->chainlit) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.4->chainlit) (1.3.1)
# Requirement already satisfied: anyio<4.0.0,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from asyncer<0.0.3,>=0.0.2->chainlit) (3.7.0)
# Requirement already satisfied: requests>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from auth0-python<5.0.0,>=4.1.1->chainlit) (2.27.1)
# Collecting pyjwt[crypto]>=2.6.0 (from auth0-python<5.0.0,>=4.1.1->chainlit)
#   Downloading PyJWT-2.7.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses_json<0.6.0,>=0.5.7->chainlit) (3.19.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /usr/local/lib/python3.10/dist-packages (from dataclasses_json<0.6.0,>=0.5.7->chainlit) (1.5.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses_json<0.6.0,>=0.5.7->chainlit) (0.9.0)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi<0.97.0,>=0.96.0->chainlit)
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 8.3 MB/s eta 0:00:00
# Collecting python-socketio>=4.6.0 (from fastapi-socketio<0.0.11,>=0.0.10->chainlit)
#   Downloading python_socketio-5.8.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai<0.28.0,>=0.27.7->chainlit) (4.65.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.0.0,>=1.10.8->chainlit) (4.6.3)
# Collecting websockets>=5.0 (from python-graphql-client<0.5.0,>=0.4.3->chainlit)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 16.2 MB/s eta 0:00:00
# Collecting opentelemetry-api==1.18.0 (from uptrace<2.0.0,>=1.18.0->chainlit)
#   Downloading opentelemetry_api-1.18.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 6.2 MB/s eta 0:00:00
# Collecting opentelemetry-exporter-otlp==1.18.0 (from uptrace<2.0.0,>=1.18.0->chainlit)
#   Downloading opentelemetry_exporter_otlp-1.18.0-py3-none-any.whl (7.0 kB)
# Collecting opentelemetry-instrumentation==0.39b0 (from uptrace<2.0.0,>=1.18.0->chainlit)
#   Downloading opentelemetry_instrumentation-0.39b0-py3-none-any.whl (24 kB)
# Collecting opentelemetry-sdk==1.18.0 (from uptrace<2.0.0,>=1.18.0->chainlit)
#   Downloading opentelemetry_sdk-1.18.0-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 12.4 MB/s eta 0:00:00
# Collecting deprecated>=1.2.6 (from opentelemetry-api==1.18.0->uptrace<2.0.0,>=1.18.0->chainlit)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting importlib-metadata~=6.0.0 (from opentelemetry-api==1.18.0->uptrace<2.0.0,>=1.18.0->chainlit)
#   Downloading importlib_metadata-6.0.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api==1.18.0->uptrace<2.0.0,>=1.18.0->chainlit) (67.7.2)
# Collecting opentelemetry-exporter-otlp-proto-grpc==1.18.0 (from opentelemetry-exporter-otlp==1.18.0->uptrace<2.0.0,>=1.18.0->chainlit)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.18.0-py3-none-any.whl (18 kB)
# Collecting opentelemetry-exporter-otlp-proto-http==1.18.0 (from opentelemetry-exporter-otlp==1.18.0->uptrace<2.0.0,>=1.18.0->chainlit)
#   Downloading opentelemetry_exporter_otlp_proto_http-1.18.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.39b0->uptrace<2.0.0,>=1.18.0->chainlit) (1.14.1)
# Collecting opentelemetry-semantic-conventions==0.39b0 (from opentelemetry-sdk==1.18.0->uptrace<2.0.0,>=1.18.0->chainlit)
#   Downloading opentelemetry_semantic_conventions-0.39b0-py3-none-any.whl (26 kB)
# Collecting backoff<3.0.0,>=1.10.0 (from opentelemetry-exporter-otlp-proto-grpc==1.18.0->opentelemetry-exporter-otlp==1.18.0->uptrace<2.0.0,>=1.18.0->chainlit)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.18.0->opentelemetry-exporter-otlp==1.18.0->uptrace<2.0.0,>=1.18.0->chainlit) (1.59.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.18.0->opentelemetry-exporter-otlp==1.18.0->uptrace<2.0.0,>=1.18.0->chainlit) (1.56.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.18.0 (from opentelemetry-exporter-otlp-proto-grpc==1.18.0->opentelemetry-exporter-otlp==1.18.0->uptrace<2.0.0,>=1.18.0->chainlit)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.18.0-py3-none-any.whl (17 kB)
# Collecting opentelemetry-proto==1.18.0 (from opentelemetry-exporter-otlp-proto-grpc==1.18.0->opentelemetry-exporter-otlp==1.18.0->uptrace<2.0.0,>=1.18.0->chainlit)
#   Downloading opentelemetry_proto-1.18.0-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: protobuf<5.0,>=3.19 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-proto==1.18.0->opentelemetry-exporter-otlp-proto-grpc==1.18.0->opentelemetry-exporter-otlp==1.18.0->uptrace<2.0.0,>=1.18.0->chainlit) (3.20.3)
# Collecting h11>=0.8 (from uvicorn<0.23.0,>=0.22.0->chainlit)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.4.0->asyncer<0.0.3,>=0.0.2->chainlit) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.4.0->asyncer<0.0.3,>=0.0.2->chainlit) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.4.0->asyncer<0.0.3,>=0.0.2->chainlit) (1.1.1)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.3.0->dataclasses_json<0.6.0,>=0.5.7->chainlit) (23.1)
# Collecting cryptography>=3.4.0 (from pyjwt[crypto]>=2.6.0->auth0-python<5.0.0,>=4.1.1->chainlit)
#   Downloading cryptography-41.0.1-cp37-abi3-manylinux_2_28_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 89.8 MB/s eta 0:00:00
# Collecting bidict>=0.21.0 (from python-socketio>=4.6.0->fastapi-socketio<0.0.11,>=0.0.10->chainlit)
#   Downloading bidict-0.22.1-py3-none-any.whl (35 kB)
# Collecting python-engineio>=4.3.0 (from python-socketio>=4.6.0->fastapi-socketio<0.0.11,>=0.0.10->chainlit)
#   Downloading python_engineio-4.4.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.14.0->auth0-python<5.0.0,>=4.1.1->chainlit) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.14.0->auth0-python<5.0.0,>=4.1.1->chainlit) (2023.5.7)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.4.0->dataclasses_json<0.6.0,>=0.5.7->chainlit) (1.0.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.6.0->auth0-python<5.0.0,>=4.1.1->chainlit) (1.15.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata~=6.0.0->opentelemetry-api==1.18.0->uptrace<2.0.0,>=1.18.0->chainlit) (3.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.6.0->auth0-python<5.0.0,>=4.1.1->chainlit) (2.21)
# Building wheels for collected packages: syncer
#   Building wheel for syncer (setup.py) ... done
#   Created wheel for syncer: filename=syncer-2.0.3-py2.py3-none-any.whl size=3436 sha256=a058b7f8ae2f7eb8cd666852f2191e73b9aa6f4b936a75a61aa2c997bf8d5f2b
#   Stored in directory: /root/.cache/pip/wheels/09/e4/36/bcaad665bcc2b672888ff2df1a5a1dc638378d8765055313cd
# Successfully built syncer
# Installing collected packages: syncer, websockets, python-engineio, python-dotenv, pyjwt, opentelemetry-semantic-conventions, opentelemetry-proto, importlib-metadata, h11, deprecated, bidict, backoff, aiofiles, watchfiles, uvicorn, starlette, python-socketio, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, cryptography, asyncer, python-graphql-client, opentelemetry-sdk, opentelemetry-instrumentation, openai, fastapi, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, fastapi-socketio, auth0-python, opentelemetry-exporter-otlp, uptrace, chainlit
# Successfully installed aiofiles-23.1.0 asyncer-0.0.2 auth0-python-4.3.0 backoff-2.2.1 bidict-0.22.1 chainlit-0.4.101 cryptography-41.0.1 deprecated-1.2.14 fastapi-0.96.1 fastapi-socketio-0.0.10 h11-0.14.0 importlib-metadata-6.0.1 openai-0.27.8 opentelemetry-api-1.18.0 opentelemetry-exporter-otlp-1.18.0 opentelemetry-exporter-otlp-proto-common-1.18.0 opentelemetry-exporter-otlp-proto-grpc-1.18.0 opentelemetry-exporter-otlp-proto-http-1.18.0 opentelemetry-instrumentation-0.39b0 opentelemetry-proto-1.18.0 opentelemetry-sdk-1.18.0 opentelemetry-semantic-conventions-0.39b0 pyjwt-2.7.0 python-dotenv-1.0.0 python-engineio-4.4.1 python-graphql-client-0.4.3 python-socketio-5.8.0 starlette-0.27.0 syncer-2.0.3 uptrace-1.18.0 uvicorn-0.22.0 watchfiles-0.19.0 websockets-11.0.3

# %%
from langchain import PromptTemplate,  LLMChain
import chainlit as cl

template = """
You are an artificial intelligence assistant. The assistant gives helpful, detailed, and polite answers to the user's questions.
Question: {question}
Answer:"""

#prompt = PromptTemplate(template=template, input_variables=["question"])
#llm_chain = LLMChain(prompt=prompt, llm=llm)
#question = "Which are neighbor countries of India"
#print(llm_chain.run(question))

@cl.langchain_factory(use_async=True)
def factory():
    prompt = PromptTemplate(template=template, input_variables=["question"])
    llm_chain = LLMChain(prompt=prompt, llm=llm)

    return llm_chain

# %% [markdown]
# AI is like the sun that shines,
# Bringing happiness and knowledge to everyone.
# It helps us in many ways,
# From finding answers to complex questions.
# AI can do amazing things,
# That we can't even imagine yet!
# AI is like a powerful tool,
# That can help us solve any riddle.
# It can even predict the future,
# Based on current situations and trends.
# AI is here to stay,
# And will be an essential element in our lives,
# Providing a better tomorrow
# and an even brighter future!

# %%
#!npm install -g localtunnel
# !curl ipecho.net/plain
# Out:
# 34.29.126.3

# %%
# !lt --port 8000
# Out:
# your url is: https://pretty-rabbits-press.loca.lt
# ^C

# %%
#!pip install pyngrok
#from pyngrok import ngrok
# Setup a tunnel to the streamlit port 8501
#public_url = ngrok.connect(port='8000')
#public_url

from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(8000)"))
#!python -m http.server 8000
# Out:
# https://tr2gu8ez2gs-496ff2e9c6d22116-8000-colab.googleusercontent.com/

# %%
# !npm install localtunnel
# Out:
# npm WARN saveError ENOENT: no such file or directory, open '/content/package.json'
# npm WARN enoent ENOENT: no such file or directory, open '/content/package.json'
# npm WARN content No description
# npm WARN content No repository field.
# npm WARN content No README data
# npm WARN content No license field.
#
# + localtunnel@2.0.2
# updated 1 package and audited 36 packages in 0.474s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# found 0 vulnerabilities

# %%
# !streamlit run myBot4_stream.py &>/content/logs.txt &

# %%
# !npx localtunnel --port 8501
# Out:
# npx: installed 22 in 1.567s
# your url is: https://sweet-women-appear.loca.lt
# ^C
